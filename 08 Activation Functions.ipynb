# %%
'''
Binary Step
Linear Activation Function
Sigmoid Function
Softmax Function
Tanh Function
Relu
Lenky Relu
ELU
GELU
SELU
Swish

# %%
'''
Binary Step

# %% [markdown]
# ![00%20Binary%20Step.jpg](attachment:00%20Binary%20Step.jpg)

# %%
'''
Linear Activation Function

# %% [markdown]
# ![01%20Linear%20Activation%20Fun.png](attachment:01%20Linear%20Activation%20Fun.png)

# %%
'''
Sigmoid Function

# %% [markdown]
# ![02%20SigmoidFunction.JPG](attachment:02%20SigmoidFunction.JPG)

# %%
'''
Softmax Function

# %% [markdown]
# ![03%20Softmax%20Function.png](attachment:03%20Softmax%20Function.png)

# %%
'''
Tanh Function

# %% [markdown]
# ![04%20Tanh.png](attachment:04%20Tanh.png)

# %%
'''
Relu

# %% [markdown]
# ![05%20Relu.png](attachment:05%20Relu.png)

# %%
'''
Lenky Relu

# %% [markdown]
# ![06%20Leaky%20Relu.png](attachment:06%20Leaky%20Relu.png)

# %%
'''
Parametric Relu

# %% [markdown]
# ![07%20Parametric%20Relu.png](attachment:07%20Parametric%20Relu.png)

# %%
'''
ELU

# %% [markdown]
# ![08%20ELU.png](attachment:08%20ELU.png)

# %%
'''
GELU

# %%
'''
SELU

# %% [markdown]
# ![10%20SELU.png](attachment:10%20SELU.png)

# %%
'''
Swish

# %% [markdown]
# ![09%20Swish.png](attachment:09%20Swish.png)
