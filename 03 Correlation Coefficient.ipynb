# %%
'''

Pearson's Correlation Coefficient 
Spearman's Rank Correlation 
ANOVA Correlation Coefficient 
Kendall's Rank Coefficient 
Bessels Correlation

# %%
'''

Feature Selection:

    - Numeric Input,Numeric Output
        - Pearson's Correlation Coefficient(Linear)
        - Spearman's Rank Correlation (Non Linear)

    - Numerical Input, Categorical Output
        - ANOVA Correlarion Coefficient(Linear)
        - Kendall's Rank Coefficient(Non Linear)

    - Categorical Input,Numnerical Output
        - ANOVA Correlarion Coefficient(Linear)
        - Kendall's Rank Coefficient(Non Linear)

    - Categorical Input,Categorical Output
        - Chi-Squared Test(Contingency Tables)
        - Multual Infomation

# %%
'''

Spearman’s coefficient is suitable for both continuous and discrete ordinal variables.
The Spearman’s rank correlation test doesn’t carry any assumptions about the distribution of the data.

# %%
'''
Pearson's Correlation Coefficient

# %% [markdown]
# ![01%20Pearson%E2%80%99s.png](attachment:01%20Pearson%E2%80%99s.png)

# %%
'''
Spearman's Rank Correlation

# %% [markdown]
# ![02%20Spearman_Rank_DifferenceMethod02.png](attachment:02%20Spearman_Rank_DifferenceMethod02.png)

# %% [markdown]
# ![03%20Person%20and%20Spearman.png](attachment:03%20Person%20and%20Spearman.png)

# %%
'''
ANOVA Correlation Coefficient

# %%
'''
Kendall's Rank Coefficient

# %% [markdown]
# ![04%20Kendall%20rank.PNG](attachment:04%20Kendall%20rank.PNG)

# %%
'''
Bessels Correlation

# %% [markdown]
# ![05%20Bessel%20Correction.PNG](attachment:05%20Bessel%20Correction.PNG)
