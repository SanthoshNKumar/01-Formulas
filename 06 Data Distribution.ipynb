# %%
'''
Normal Distribution
Bernoulli Distribution
Binominal Distribution
Poission Distribution

# %%
'''
Normal Distribution

# %% [markdown]
# ![01%20Normal%20Distribution.PNG](attachment:01%20Normal%20Distribution.PNG)

# %%
'''
Bernoulli Distribution

# %% [markdown]
# ![02%20Bernoulli%20Distribution.PNG](attachment:02%20Bernoulli%20Distribution.PNG)

# %%
'''
Binominal Distribution

# %% [markdown]
# ![03%20Binominal%20Distribution.png](attachment:03%20Binominal%20Distribution.png)

# %%
'''
Poission Distribution

# %% [markdown]
# ![02%20Poission%20Distribution.PNG](attachment:02%20Poission%20Distribution.PNG)

# %%
'''
Uniform Distribution

# %% [markdown]
# ![05%20Uniform%20Distribution.PNG](attachment:05%20Uniform%20Distribution.PNG)

# %%
'''

Exponential Distribution : Inverse of the Poisson distribution.The events in consideration are independent of each other.

# %% [markdown]
# ![06%20Exponential%20Distribution.PNG](attachment:06%20Exponential%20Distribution.PNG)

# %%
'''
Log Normal Distribution

# %% [markdown]
# ![07%20Log%20Normal%20Distribution.PNG](attachment:07%20Log%20Normal%20Distribution.PNG)
