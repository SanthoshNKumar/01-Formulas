# %%
'''
Scaling:Standardzation(Z Score)
Scaling: Min-Max Scaling (Normalization)

# %%
'''
Standardzation

# %% [markdown]
# ![01%20Standardization_zscore.PNG](attachment:01%20Standardization_zscore.PNG)

# %%
'''
Min-Max Scaling (Normalization)

# %% [markdown]
# ![02%20MinMaxScaling.PNG](attachment:02%20MinMaxScaling.PNG)
