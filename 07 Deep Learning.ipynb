# %%
'''

ANN
RNN
LSTM
CNN Filter output
Weight Initilization
Xavier initialization(Uniform Distribution)
Xavier initialization(Normal Distribution)
He initialization(Uniform Distribution)
He initialization(Normal Distribution)

# %%
'''
Single Neuron

# %% [markdown]
# ![01%20Neuron.png](attachment:01%20Neuron.png)

# %%
'''
ANN

# %% [markdown]
# ![02%20ANN'.png](attachment:02%20ANN'.png)

# %%
'''
RNN

# %% [markdown]
# ![03%20RNN_Cell.PNG](attachment:03%20RNN_Cell.PNG)

# %%
'''
LSTM

# %% [markdown]
# ![04%20LSTM_Gates01.PNG](attachment:04%20LSTM_Gates01.PNG)

# %%
'''
CNN Output Dimention Calculation

# %% [markdown]
# ![05%20CNN%20Output%20Dimention.PNG](attachment:05%20CNN%20Output%20Dimention.PNG)

# %%
'''
CNN Applying Filters or kernels on Image

# %% [markdown]
# ![05%20CNN%20Image%20and%20Kernel.png](attachment:05%20CNN%20Image%20and%20Kernel.png)

# %%
'''
CNN Max pooling

# %% [markdown]
# ![05%20CNN%20Max%20Pooling.png](attachment:05%20CNN%20Max%20Pooling.png)

# %%
'''
CNN Average pooling

# %% [markdown]
# ![05%20CNN%20Average%20Pooling.png](attachment:05%20CNN%20Average%20Pooling.png)

# %%
'''
CNN Multi Input and Single Output

# %% [markdown]
# ![05%20CNN%20Multi%20Input%20and%20Single%20Output.png](attachment:05%20CNN%20Multi%20Input%20and%20Single%20Output.png)

# %%
# Output size of the max Pool Layer

# %% [markdown]
# ![MaxPooling.png](attachment:MaxPooling.png)

# %%
'''
Weight Initilization

# %%
'''
Xavier initialization(Uniform Distribution)

'''
Xavier initialization(Normal Distribution)

'''
He initialization(Uniform Distribution)

'''
He initialization(Normal Distribution)

# %% [markdown]
# ![Weight%20Initialization%20Formula.PNG](attachment:Weight%20Initialization%20Formula.PNG)
