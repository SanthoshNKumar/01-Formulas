# %%
# Probablity

# %%
# Conditional Probability

# %% [markdown]
# ![Conditional%20Probability.png](attachment:Conditional%20Probability.png)

# %%
# Union

# %% [markdown]
# ![Find_IntersectionOfTwoSets.PNG](attachment:Find_IntersectionOfTwoSets.PNG)

# %%
# Intersection

# %% [markdown]
# ![Find_UnionOfTwoSets.PNG](attachment:Find_UnionOfTwoSets.PNG)

# %%
# Venn Diagram

# %% [markdown]
# ![Venn_Diagram.png](attachment:Venn_Diagram.png)
