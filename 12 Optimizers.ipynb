# %%
'''
Optimizers
    1.Gradient Descent
    2.Momentum
    3.NAG Update Rule
    4.AdaGrad
    5.RMSProp
    6.Adam

# %%
'''
Gradient Descent : Stochastic Gradient Descent (SGD):
    -

# %% [markdown]
# ![01%20GD_SGD.png](attachment:01%20GD_SGD.png)

# %%
'''
Gradient Descent :Batch Gradient Descent
    - Weights are updated after computing the gradient of error with respect to the entire training set

# %% [markdown]
# ![02%20GD_Batch%20GD.png](attachment:02%20GD_Batch%20GD.png)

# %%
'''
Gradient Descent : Mini Batch Gradient Descent
    - Parameters are updated after computing the gradient of error with respect to a subset( n Samples) of the training set

# %% [markdown]
# ![03%20GD_Mini%20Batch%20GD.png](attachment:03%20GD_Mini%20Batch%20GD.png)

# %%
'''
Momentum

# %% [markdown]
# ![04%20Momentum.png](attachment:04%20Momentum.png)

# %%
'''
NAG

# %% [markdown]
# ![05%20NAG.PNG](attachment:05%20NAG.PNG)

# %%
'''
AdaGrad

# %% [markdown]
# ![05%20AdaGrad.PNG](attachment:05%20AdaGrad.PNG)

# %%
'''
RMS Prop

# %% [markdown]
# ![07%20RMSProp.PNG](attachment:07%20RMSProp.PNG)

# %%
'''
Adam

# %% [markdown]
# ![08%20Adam.png](attachment:08%20Adam.png)
