# %%
'''
MSE
MAE
RMSE
RMSLE
R2 Score
Adjusted R2 Score
Explained variance score

SSE
SST
SSR

Acccuracy
Precision
Recall
True Positive rate
False Positive rate
Sensitivity
Specificity
Misclassification Rate
ROC
AUC
F1 Score

# %%
'''
MAE : It measures the average of the residuals in the dataset.

# %% [markdown]
# ![01%20MAE.png](attachment:01%20MAE.png)

# %%
'''
MSE : It measures the variance of the residuals.

# %% [markdown]
# ![02%20MSE.png](attachment:02%20MSE.png)

# %%
'''
RMSE : It measures the standard deviation of residuals.
The RSME is measured of how spread out the residuals are in the dataset.

# %% [markdown]
# ![03%20RMSE.png](attachment:03%20RMSE.png)

# %%
'''
RMSLE : Root-mean-square logarithm Error

# %% [markdown]
# ![04%20RMSLE.png](attachment:04%20RMSLE.png)

# %%
'''
R2 Score : Coefficient of Determination
    - R-Squared, also known as the Coefficient of Determination, is a value between 0 and 1 that measures how well our 
      regression line fits our data
    - The closer R-Squared is to 1 or 100% the better our model will be at predicting our dependent variable

# %% [markdown]
# ![05%20R%20Square.PNG](attachment:05%20R%20Square.PNG)

# %%
'''
Adjusted R2 Score

# %% [markdown]
# ![06%20%20Adjusted%20R%20Square.png](attachment:06%20%20Adjusted%20R%20Square.png)

# %%
'''
Explained variance score

# %%
'''
SSR :

# %% [markdown]
# ![08%20SSR.PNG](attachment:08%20SSR.PNG)

# %%
'''
SST or TSS:

# %% [markdown]
# ![09%20SST.PNG](attachment:09%20SST.PNG)

# %%
'''
SSE:

# %% [markdown]
# ![10%20SSE.PNG](attachment:10%20SSE.PNG)

# %%
'''
Confusion Matrix

# %% [markdown]
# ![11%20Confusion%20matrix.PNG](attachment:11%20Confusion%20matrix.PNG)

# %%
'''
Acccuracy : General information about how many samples are misclassified

# %% [markdown]
# ![12%20Accuracy.PNG](attachment:12%20Accuracy.PNG)

# %%
'''
Precision : Number of true positives divided by the total number of elements labeled as belonging to the positive class

# %% [markdown]
# ![13%20Precision.PNG](attachment:13%20Precision.PNG)

# %%
'''
Recall or True Positive rate or Sensitivity

# %% [markdown]
# ![13%20Recall.png](attachment:13%20Recall.png)

# %%
'''
True Positive rate : Proportion of positive instances classified correctly

# %% [markdown]
# ![14%20TPR.PNG](attachment:14%20TPR.PNG)

# %%
'''
False Positive rate : Proportion of negative instances classified incorrectly

# %% [markdown]
# ![15%20FPR.PNG](attachment:15%20FPR.PNG)

# %%
'''
True Negative Rate

# %% [markdown]
# ![16%20TNR.PNG](attachment:16%20TNR.PNG)

# %%
'''
False Negative Rate

# %% [markdown]
# ![17%20FNR.PNG](attachment:17%20FNR.PNG)

# %%
'''
Sensitivity : It is same as above recall or  True Positive rat

# %% [markdown]
# ![14%20TPR.PNG](attachment:14%20TPR.PNG)

# %%
'''
Specificity : It is same as above True Negative Rate

# %% [markdown]
# ![16%20TNR.PNG](attachment:16%20TNR.PNG)

# %%
'''
Misclassification Rate or  Error rate

# %% [markdown]
# ![18%20MisclassificarionRate.PNG](attachment:18%20MisclassificarionRate.PNG)

# %%
'''
F1 Score

# %% [markdown]
# ![19%20F1%20Score.PNG](attachment:19%20F1%20Score.PNG)

# %%
'''
ROC Curve : Receiver operating characteristic
    - Plotting true positive rates against false positive rates at different thresholds.
    - It shows the performance of the classification model at different thresholds

# %% [markdown]
# ![20%20ROC.PNG](attachment:20%20ROC.PNG)

# %%
'''
AUC

# %% [markdown]
# ![21%20AUC.png](attachment:21%20AUC.png)
