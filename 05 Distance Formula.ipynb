# %%
'''
MinKowsi
Manhattan
Euclidean
Cosine Similarity
Jaccard Coeffcient

# %%
'''
MinKowsi

# %% [markdown]
# ![01_Minkowski.png](attachment:01_Minkowski.png)

# %%
'''
Manhattan

# %% [markdown]
# ![02_Manhattan.png](attachment:02_Manhattan.png)

# %%
'''
Euclidean

# %% [markdown]
# ![03_Euclidean.png](attachment:03_Euclidean.png)

# %%
'''
Cosine Similarity

# %% [markdown]
# ![04_Cosine_Similarity.png](attachment:04_Cosine_Similarity.png)

# %%
'''
Jaccard Coeffcient

# %% [markdown]
# ![05%20Jaccard%20Distance.png](attachment:05%20Jaccard%20Distance.png)
