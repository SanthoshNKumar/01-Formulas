# %%
'''
Mean
Weighted Mean
Trimmed mean
Median
Weighted Median
Mode
Range
Quartile
Variance
Standard Deviation
Mean Absolute Deviation
Standard Error
Covariance
Correlation Coefficient
Percentile
Quartile
IQR

Empherical Formula
Confidance Intervals values

Hypothesis testing
    T test
    F test
    ANOVA
    Z-Score
    Chi-Squared Test
    Student t Test Statistics

Data Distribution
    Kurthosis
    Skewness

# %%
'''
Mean

# %% [markdown]
# ![01%20Mean.png](attachment:01%20Mean.png)

# %%
'''
Weighted Mean :

A weighted mean is a kind of average. Instead of each data point contributing equally to the final mean, some data points 
contribute more “weight” than others.

# %% [markdown]
# ![02%20Weighted%20mean.PNG](attachment:02%20Weighted%20mean.PNG)

# %%
'''
Trimmed Mean(Truncated Mean)
    - It is similar to a “regular” mean (average), but it trims any outliers.
    - Outliers can affect the mean (especially if there are just one or two very large values).
    - So a trimmed mean can often be a better fit for data sets with erratic high or low values or for extremely skewed 
      distributions.

# %% [markdown]
# ![03%20Trimmed%20mean.png](attachment:03%20Trimmed%20mean.png)

# %%
'''
Median

# %% [markdown]
# ![04%20Median.PNG](attachment:04%20Median.PNG)

# %%
'''

Weighted Median

# %%
'''

Mode : The mode is simply the number which appears most often.

# %% [markdown]
# ![06%20Mode.PNG](attachment:06%20Mode.PNG)

# %%
'''

Range : Difference between the maximum and minimum value of the set

# %% [markdown]
# ![07%20Range.PNG](attachment:07%20Range.PNG)

# %%
'''
Variance

# %% [markdown]
# ![09%20Variance.png](attachment:09%20Variance.png)

# %%
'''
Standard Deviation: It is a Sqreroot of Variance

# %% [markdown]
# ![10%20Standard%20Deviation.png](attachment:10%20Standard%20Deviation.png)

# %%
'''
Mean Absolute Deviation

# %%
'''
Standard Error :The standard error is the approximate standard deviation of a statistical sample population

# %% [markdown]
# ![12%20StandardError.PNG](attachment:12%20StandardError.PNG)

# %%
'''
Covariance : covariance is a measure of the relationship between two random variables

# %% [markdown]
# ![13%20Covariance.png](attachment:13%20Covariance.png)

# %%
'''
Correlation Coefficient : Correlation measures the strength of the relationship between variables. Correlation is the scaled 
                          measure of covariance.It is dimensionless. In other words, the correlation coefficient is always a 
                          pure value and not measured in any unit

# %% [markdown]
# ![14%20CorrelationFromCovariance.PNG](attachment:14%20CorrelationFromCovariance.PNG)

# %%
'''
Percentage

# %% [markdown]
# ![15%20Percentage.PNG](attachment:15%20Percentage.PNG)

# %%
'''
Quartile : It Means 3 Different perceniles (Q1,Q2(Median),Q3)

# %% [markdown]
# ![17%20Quartile.PNG](attachment:17%20Quartile.PNG)

# %%
'''
Percentile :

# %% [markdown]
# ![16%20Percentile.png](attachment:16%20Percentile.png)

# %%
'''
IQR : Inter quartile Range

# %% [markdown]
# ![18%20IQR.png](attachment:18%20IQR.png)

# %%
'''
Empherical Formula

# %% [markdown]
# ![19%20Empherical%20Rule.jpg](attachment:19%20Empherical%20Rule.jpg)

# %%
'''
Confidence Intervals

# %% [markdown]
# ![Confidenece%20Intervals_formula.png](attachment:Confidenece%20Intervals_formula.png)

# %%
'''
Confidence Intervals for Unknown Mean and Known Standard Deviation

# %%
'''
Confidence Intervals for Unknown Mean and Unknown Standard Deviation

# %%
'''
Confidance Intervals for Normal Distribution

# %%
'''
Confidance Intervals for t Distribution

# %%
'''
Confidance Intervals for Normal Distribution

# %%
'''
F test : The F-Test to Compare Two Variances.

# %% [markdown]
# ![21%20F%20Test.png](attachment:21%20F%20Test.png)

# %%
'''
ANOVA : F test and ANOVA more or less same, where we find mean square between samples and mean square witnin the samples

# %%
'''
Skewness

# %% [markdown]
# ![25%20Skewness.png](attachment:25%20Skewness.png)

# %%
'''
Kurthosis

# %% [markdown]
# ![24%20Kurthosis.png](attachment:24%20Kurthosis.png)

# %% [markdown]
# ## Hypothesis Testing

# %%
'''
Z-Test (One Sample Z Test for Single Mean)

# %% [markdown]
# ![22%20Z%20Test_One%20Sample.png](attachment:22%20Z%20Test_One%20Sample.png)

# %%
'''
T test (1.One-sample t-test or Student t Test) :
    - It is used to determine if the sample is significantly different from the population

# %% [markdown]
# ![20%20T%20test_One%20Sample.png](attachment:20%20T%20test_One%20Sample.png)

# %%
'''
T test (2.Two-sample t-test) :
    - Two samples are to be compared, then a two-sample t-test is to be used, and its formula is expressed using respective 
      sample means, sample standard deviations, and sample sizes

# %% [markdown]
# ![20%20T%20test_Two%20Sample.png](attachment:20%20T%20test_Two%20Sample.png)

# %%
'''

Z-Test (Two Sample Z Test for Difference  of two independent random samples)

# %% [markdown]
# ![22%20Z%20Test_Two%20Sample.png](attachment:22%20Z%20Test_Two%20Sample.png)

# %%
'''
Chi-Squared Test

# %% [markdown]
# ![23%20ChiSquared%20Test_formula.png](attachment:23%20ChiSquared%20Test_formula.png)

# %% [markdown]
# ## Data Distribution

# %% [markdown]
# ### Categorical Distribution

# %%
'''
Distribution:Bernoulli Distribution

# %% [markdown]
# ![02%20Bernoulli%20Distribution.PNG](attachment:02%20Bernoulli%20Distribution.PNG)

# %%
'''

Distribution: Binominal Distribution

# %% [markdown]
# ![Binominal%20Distribution.png](attachment:Binominal%20Distribution.png)

# %%
'''

Distribution: Poission Distribution

# %% [markdown]
# ![29%20Poission%20Distribution.png](attachment:29%20Poission%20Distribution.png)

# %%
'''
Unifrom Distribution

# %% [markdown]
# ![05%20Uniform%20Distribution.PNG](attachment:05%20Uniform%20Distribution.PNG)

# %% [markdown]
# ### Continues Distribution

# %%
'''

Distribution: Normal Distribution

# %% [markdown]
# ![26%20Normal%20Distribution.png](attachment:26%20Normal%20Distribution.png)

# %%
'''
Exponentil Distribution

# %% [markdown]
# ![06%20Exponential%20Distribution.PNG](attachment:06%20Exponential%20Distribution.PNG)

# %%
'''
T-Distribution

# %%
'''
Log Normal Distribution

# %% [markdown]
# ![07%20Log%20Normal%20Distribution.PNG](attachment:07%20Log%20Normal%20Distribution.PNG)
