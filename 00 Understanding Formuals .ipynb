# %% [markdown]
# ### Mathematics

# %%
'''
###### Calculas

        1. Differentiation (Derivatives)
            - Chain Rule

        2. Integration (Inverses of derivatives)


###### Geometry

        1. Distance Formula
        
            1. Euclidean distance
            2. Manhattan distance 
            3. Minkowski
            4. Hamming
            5. Cosine Similarity
            6. L2 and L1 Norm

###### Linear Algebra

        1. Equation for Stright Line
        2. Scalar
        3. Vector
        4. Matrix
        5. Eigen Vector and Values

###### Trignometry

        1. Right angle Traiangle
        2. Sine,Cosine, and Tangent

# %% [markdown]
# ### Statistics

# %%
'''
    1. Mean
    2. Weighted Mean
    3. Trimmed mean
    4. Median
    5. Weighted Median
    6. Mode
    7. Range
    8. Quartile
    9. Variance
    10. Standard Deviation
    11. Mean Absolute Deviation
    12. Standard Error
    13. Covariance
    14. Correlation Coefficient
    15. Percentile
    16. Quartile
    17. IQR
    18. Empherical Formula
    19. Confidance Intervals values
    
    20. Hypothesis testing
        - T test
        - F test
        - ANOVA
        - Z-Score
        - Chi-Squared Test
        - Student t Test Statistics

    21. Data Distribution
        - Kurthosis
        - Skewness

# %% [markdown]
# ### Probability

# %%
'''
    1. Venn Diagram
    2. Probability Events    
    3. Independent Events
    4. Dependent Events
    5. Conditional Probability
    6. Union
    7. Intersection
    8. Jaccard similarity coefficient
    9. Bayes Theorem
    10. PDF (Probability Density Function)
    11. CDF (Cumulative Distribution Function)

# %% [markdown]
# ### Correlation Coefficient

# %%
'''
    1. Pearson's Correlation Coefficient 
    2. Spearman's Rank Correlation 
    3. ANOVA Correlation Coefficient 
    4. Kendall's Rank Coefficient 
    5. Bessels Correlation

# %% [markdown]
# ### Scaling

# %%
'''
    1. Scaling:Standardzation(Z Score)
    2. Scaling: Min-Max Scaling (Normalization)

# %% [markdown]
# ### Distance Formula

# %%
'''
    1. Euclidean distance
    2. Manhattan distance 
    3. Minkowski
    4. Hamming
    5. Cosine Similarity
    6. Jaccard Coefficient
    7. L2 and L1 Norm

# %% [markdown]
# ### Data Distribution

# %%
'''
    1.Normal Distribution
    2.Bernoulli Distribution
    3.Binominal Distribution
    4.Poission Distribution

# %% [markdown]
# ### Loss Function

# %%
'''
    1.Probabilistic Loss Function
    2.Binary Crossentropy (BCE)
    3.Categorical Crossentropy or SoftMax Loss
    4.Sparse Categorical Crossentropy
    5.Poisson
    6.Kullback-Leibler Divergence

    7.Regression Loss Function
    8.Mean Squared error
    9.Mean Absolute Error
    10.Mean Absolute percentage error
    11.Mean Squared Logarithmic Error
    12.Huber

    13.Hinge losses
    14.Hinge
    15.Squared Hinge
    16.Categorical Hinge

# %% [markdown]
# ### Metricss

# %%
'''
    1.MSE
    2.MAE
    3.RMSE
    4.RMSLE
    5.R2 Score
    6.Adjusted R2 Score
    7.Explained variance score

    8.SSE
    9.SST
    10.SSR

    11.Acccuracy
    12.Precision
    13.Recall
    14.True Positive rate
    15.False Positive rate
    16.Sensitivity
    17.Specificity
    18.Misclassification Rate
    19.ROC
    20.AUC
    21.F1 Score

# %% [markdown]
# ### Optimizers

# %%
'''
    1.Gradient Descent
    2.Momentum
    3.NAG Update Rule
    4.AdaGrad
    5.RMSProp
    6.Adam

# %% [markdown]
# ### Activation Function

# %%
'''
    1.Binary Step
    2.Linear Activation Function
    3.Sigmoid Function
    4.Softmax Function
    5.Tanh Function
    6.Relu
    7.Lenky Relu
    8.ELU
    9.GELU
    10.SELU
    11.Swish

# %% [markdown]
# ### Machine Learning

# %%
'''
    1.Normal Equation
    2.Linear Regression
        - Ridge Regression
        - Lascco Regresssion
        - Elastic Regression
    3.Logistic Regression
    4.Decision Trees
    5.Naive Bayes Theorem
    6.SVM
    7.KNN
    8.RandomForest
    9.AdaBoost(Adaptive Boosting)
    10.Gradiest Boosting
    11.XG Boost
    12.Voting Classifer

# %% [markdown]
# ### Deep Learning

# %%
'''
    1.ANN
    2.RNN
    3.LSTM
    4.CNN Filter output
    5.Weight Initilization
    6.Xavier initialization(Uniform Distribution)
    7.Xavier initialization(Normal Distribution)
    8.He initialization(Uniform Distribution)
    9.He initialization(Normal Distribution)

# %% [markdown]
# ### CNN

# %%
'''
    1. Strides
    2. Find How many filter(Kernel) should I use
    3. Find output Dimention
    4. Total Parameters in Convloution
    5. Falttering
    6. Relu Activation Function
    7. Fully Connected Layer (ANN)
    8. Softmax

# %% [markdown]
# ### NLP

# %%
'''
    1.TF : Term Frequency
    2.IDF : Inverse Document Frequency
    
    3. Cosine Similarity
    4. Jaccard Coefficient
